# %% [markdown]
# ### 실습 문제
#
# Vision 기능으로 **웹 이미지 URL**을 분석하세요.
#
# 1. 분석할 이미지의 공개 URL을 하나 준비하세요.
# 2. `input` 에 `input_text`(질문)와 `input_image`(`image_url`)를 함께 구성하세요.
# 3. 이미지에 무엇이 있는지 한국어로 설명하도록 요청하고 결과를 출력하세요.
#
# ### 테스트 입력 예시
#
# - 임의의 풍경/사물 사진 URL → `"이 이미지에 무엇이 보이는지 한국어로 설명해줘."`

# %% [markdown]
# ## 정답

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
client = OpenAI()

Model = "gpt-5-nano"

# %%
# 분석할 공개 이미지 URL (원하는 이미지로 교체 가능)
url = "https://upload.wikimedia.org/wikipedia/commons/3/3a/Cat03.jpg"

response = client.responses.create(
    model=Model,
    input=[
        {
            "role": "user",
            "content": [
                {"type": "input_text", "text": "이 이미지에 무엇이 보이는지 한국어로 설명해줘."},
                {"type": "input_image", "image_url": url},
            ],
        }
    ],
)

print(response.output_text)
# Out:
# 주황색 털을 가진 고양이가 카메라를 향해 다가와 정면으로 바라보고 있다. 얼굴이 화면 중심에 크게 보이고, 노란빛이 도는 큰 눈이 인상적이다. 길고 흰 수염과 뾰족한 귀가 또렷하다. 털은 부드럽고 줄무늬가 있으며, 배경은 흐릿하게 처리되어 있다. 전반적으로 따뜻한 분위기의 고양이 얼굴 초상 사진이다.
