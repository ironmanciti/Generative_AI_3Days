# %% [markdown]
# # Tools (도구)
#
# OpenAI 플랫폼에서 사용할 수 있는 도구에 대한 개요는 다음과 같습니다.
#
# | 도구 | 설명 |
# |---|---|
# | Function calling | 커스텀 코드를 호출하여 모델에 추가 데이터 및 기능 제공 |
# | Web search | 인터넷 데이터를 모델 응답 생성에 포함 |
# | Remote MCP servers | MCP 서버를 통해 모델에 새로운 기능 추가 |
# | Skills | 버전 관리된 스킬 번들을 호스팅 환경에 업로드하여 재사용 |
# | Shell | 호스팅 컨테이너 또는 로컬 런타임에서 쉘 명령 실행 |
# | Computer use | 모델이 컴퓨터 인터페이스를 제어하는 에이전틱 워크플로우 생성 |
# | Image generation | GPT Image를 사용하여 이미지 생성 또는 편집 |
# | File search | 업로드된 파일 내용을 검색하여 응답 생성 시 컨텍스트로 활용 |
# | Tool search | 관련 도구를 동적으로 로드하여 토큰 사용량 및 지연시간 최적화 |
#
# ### 내장 도구 비용
#
# * 참고 : [Built-in tools Pricing](https://openai.com/api/pricing/)

# %%
from dotenv import load_dotenv
load_dotenv() # read local .env file
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

Model = "gpt-5-nano"

# %% [markdown]
# ### 웹검색 (Web Search)
# 모델이 응답을 생성하기 전에 최신 정보를 웹에서 검색할 수 있도록 허용

# %%
response = client.responses.create(
    model=Model,
    tools=[{"type": "web_search"}],
    input="오늘 한국의 종합주가지수는 얼마입니까?"
)

print(response.output_text)
# Out:
# 오늘(2026년 6월 11일) 기준으로 한국의 종합주가지수(KOSPI, KS11)의 최신 수치는 다음과 같습니다.
#
# - 현재가(KOSPI): 약 7,669.28 포인트(실시간 데이터, 한국 시간 기준 22:00 시점)
# - 당일 변동: -64.30 포인트, -0.83%
# - 당일 등락 범위: 7,394.46 ~ 7,800.62
# - 데이터 출처: Investing.com의 KOSPI 페이지
#
# 참고로 이 값은 실시간으로 변동될 수 있습니다. 원하시면 실시간 차트나 최근 일정 기간(1주/1개월)의 변동 내역도 함께 확인해 드리겠습니다. ([investing.com](https://www.investing.com/indices/kospi))

# %% [markdown]
# - 사용자 위치 지정

# %%
response = client.responses.create(
    model=Model,
    tools=[{
        "type": "web_search",
        "user_location": {
            "type": "approximate",
            "country": "KR",
            "city": "서울"
        }
    }],
    input="가로수 길에서 제일 핫한 레스토랑이 어디인가요?",
)

print(response.output_text)
# Out:
# 가로수길에서 “제일 핫한 레스토랑”은 취향과 날짜에 따라 달라지지만, 지금 많이 입에 오르는 곳들을 몇 군데 꼽아 드리겠습니다. 아래는 2026년 초·중반 뉴스/리스트에서 자주 언급되는 곳들입니다.
#
# - 토우베(TOUBE)
#   - 컨셉: 가로수길 인근의 파인다이닝으로, 일본식-프렌치 코스로 셰프가 오픈 키친에서 바로 플레이팅하는 바 다이닝
#   - 위치/시간대: 강남구 도산대로11길 31-10 B1 (신사역 8번 출구 도보 약 5–6분) / 매일 12:00–22:00
#   - 특징/가격대: 런치 코스 약 3.9만원대, 디너 코스 약 6.9만원대(오픈 기념 특별가로 안내되는 경우가 많음)
#   - 출처: 식신 TOP 4 항목에 수록, 위치 및 운영시간 등 상세 정보. ([siksinhot.com](https://www.siksinhot.com/theme/magazine/11191))
#
# - 네기다이닝라운지(Negi Dining Lounge)
#   - 컨셉: 사케·와인 등 주류를 갖춘 라운지형 이자카야/갓포 다이닝, 코스 위주와 단품 모두 가능
#   - 위치/시간대: 강남구 도산대로15길 18, 4층
#   - 가격/메뉴: 코스 약 15만원대(후기 기준), 모듬 사시미 등 다양한 단품도 제공
#   - 특징: 오픈 키친과 바 좌석 중심의 고급스러운 분위기, 프라이빗룸 가능
#   - 출처: 식신 기사에 위치·가격·메뉴 특징 기재. ([siksinhot.com](https://www.siksinhot.com/theme/magazine/11191))
#
# - 이끼롤까스 가로수길본점
#   - 컨셉: 롤까스(돈까스를 롤 형태로 말아 튀긴 퓨전 요리) 전문점, 셀프바가 있는 독특한 아이덴티티
#   - 위치/특징: 강남구 강남대로152길 64 지하1층, 차분한 분위기의 지하 매장, 셀프바 운영
#   - 메뉴 포인트: 스파이시치즈 롤까스, 버섯치즈 롤까스 등 다양한 롤까스와 간단한 사이드
#   - 출처: 식신의 소개 및 매장 정보 기사/연결 포함. ([siksinhot.com](https://www.siksinhot.com/theme/magazine/11191))
#
# - 트라가 가로수길점(Traga Garosugil)
#   - 컨셉: 정통 스페인 요리를 한데 모은 코스/세트 구성이 매력인 레스토랑
#   - 위치/특징: 강남구 압구정로2길 18, 신사역 도보 약 10분
#   - 가격대: 다인 세트 기준 1인 약 3만원대 예시(구성에 따라 변동)
#   - 출처: 식신 기사에 코스 구성과 가격대 안내. ([siksinhot.com](https://www.siksinhot.com/theme/magazine/11191))
#
# 참고로 트렌드 관점에서도 2026년 봄 가로수길의 맛집 트렌드를 다룬 기사들이 현재의 핫스팟으로 이들 업장을 언급합니다. 예를 들어, 데일리투어의 2026년 봄 가로수길 맛집 6곳 추천 기사에서도 이 거리의 트렌디한 장소들을 다루고 있습니다. ([dailytour.co.kr](https://dailytour.co.kr/garosugil-food-guide/))
#
# 참고 및 팁
# - “핫하다”는 시간대(주말/점심피크 vs 주중 저녁), 예약 여부, 인원수 등에 따라 달라질 수 있습니다. 방문 전 예약 확인을 권합니다.
# - 원하시는 예산대, 분위기(캐주얼 vs 럭셔리), 요리 종류(일식/스페인/퓨전 등)나 데이트/회식 여부를 알려주시면, 날짜별로 실시간 예약 가능 여부도 확인해 드리겠습니다.
#
# 원하신다면 지금 날짜(예: 특정 요일과 시간) 기준으로 실제 재고/예약 가능 여부를 확인해 드리겠습니다. 어떤 분위기와 예산으로 가실지 알려주실래요?

# %% [markdown]
# ### File Search

# %%
# "Financial Statements"라는 벡터 스토어 생성
vector_store = client.vector_stores.create(name="Financial Statements")
 
# OpenAI에 업로드할 파일 준비
file_paths = ["재무제표/LG엔솔.txt", "재무제표/네이버.txt"]
file_streams = [open(path, "rb") for path in file_paths]
 
# 업로드 및 폴링 SDK 도우미를 사용하여 파일을 업로드하고 벡터 스토어에 추가,
# 파일 배치의 완료 상태를 폴링합니다.
file_batch = client.vector_stores.file_batches.upload_and_poll(
  vector_store_id=vector_store.id, files=file_streams
)
 
# 이 작업의 결과를 보기 위해 상태 및 파일 개수를 출력할 수 있습니다.
print(file_batch.status)
print(file_batch.file_counts)
# Out:
# completed
# FileCounts(cancelled=0, completed=2, failed=0, in_progress=0, total=2)

# %%
response = client.responses.create(
    model=Model,
    input="2023년 NAVER와 LG에너지솔루션의 당기순이익은 각각 얼마이며, 어느 회사의 당기순이익이 더 높았나요?",
    tools=[{
        "type": "file_search",
        "vector_store_ids": [vector_store.id]
    }]
)

print(response.output_text)
# Out:
# 요청하신 2023년 수치를 파일에서 확인해보면:
#
# - NAVER: 2023년 당기순이익 1,406 십억원 (약 1.406조 원)으로 제시됩니다.
# - LG에너지솔루션: 2023년 당기순이익 1,638 십억원 (약 1.638조 원)으로 제시됩니다.
#
# 두 회사 중 더 높은 당기순이익은 LG에너지솔루션이며, 차이는 약 0.232조 원(2320억원)입니다.

# %%
response = client.responses.create(
    model=Model,
    input="2022년 NAVER 의 ROE는 얼마인가요?",
    tools=[{
        "type": "file_search",
        "vector_store_ids": [vector_store.id]
    }]
)

print(response.output_text)
# Out:
# 2022년 NAVER의 ROE는 3.3%입니다.

# %% [markdown]
# ### Remote MCP
# - 모델이 원격 MCP 서버를 사용하여 작업을 수행할 수 있도록 허용
# - 모델 컨텍스트 프로토콜 (MCP)은 애플리케이션이 LLM에 도구와 컨텍스트를 제공하는 방식을 표준화
# - Responses API의 MCP 도구를 통해 개발자는 모델에 원격 MCP 서버 에 호스팅된 도구에 대한 액세스 권한을 부여
# - 원격 MCP 서버는 개발자와 조직이 인터넷을 통해 관리하며, Responses API와 같은 도구를 MCP 클라이언트에 제공하는 MCP 서버

# %%
#  DeepWiki MCP 서버를 사용하여 거의 모든 공개 저장소에 대해 질문
resp = client.responses.create(
    model=Model,
    tools=[
        {
            "type": "mcp",
            "server_label": "deepwiki",
            "server_url": "https://mcp.deepwiki.com/mcp",
            "require_approval": "never",
        },
    ],
    input="openai/openai-python 저장소의 전체 구조와 핵심 모듈을 설명해 주세요.",
)

print(resp.output_text)
# Out:
# 다음은 openai/openai-python 저장소의 “전체 구조”와 핵심 모듈(컴포넌트)에 대한 요약입니다. 저장소의 위키 구조를 기준으로 정리했고, 필요 시 각 항목에 대해 더 깊이 파고들 수 있도록 안내합니다.
#
# 1) 저장소의 큰 구조(구조 축)
# - 1 Overview
#   - 1.1 Architecture Overview
#   - 1.2 Project Configuration and Dependencies
# - 2 Installation and Setup
#   - 2.1 Client Configuration
#   - 2.2 Azure OpenAI Configuration
#   - 2.3 Module-Level API Usage
# - 3 Core Client Classes
#   - 3.1 OpenAI and AsyncOpenAI Clients
#   - 3.2 HTTP Client Foundation
#   - 3.3 Request and Response Processing
#   - 3.4 Error Handling and Retry Logic
#   - 3.5 Pagination
#   - 3.6 Response Wrappers
#   - 3.7 Authentication and Workload Identity
# - 4 API Resources and Endpoints
#   - 4.1 Chat Completions API
#     - 4.1.1 Parameters and Configuration
#     - 4.1.2 Streaming Chat Completions
#     - 4.1.3 Parsed Responses and Structured Outputs
#   - 4.2 Responses API
#     - 4.2.1 Multi-Modal Inputs and Tool Integration
#     - 4.2.2 Conversation and State Management
#   - 4.3 Assistants API (Beta)
#     - 4.3.1 Assistants and Configuration
#     - 4.3.2 Threads and Messages
#     - 4.3.3 Runs and Execution
#     - 4.3.4 Streaming Assistant Events
#   - 4.4 Fine-Tuning API
#   - 4.5 Embeddings and Vector Stores
#   - 4.6 File Management and Uploads
#   - 4.7 Audio, Images, and Video APIs
#   - 4.8 Additional API Resources
#   - 4.9 Realtime API (Beta)
# - 5 Data Types and Type System
#   - 5.1 Type System Overview
#   - 5.2 Request Parameter Types
#   - 5.3 Response Types and Models
#   - 5.4 Pydantic Models and BaseModel
#   - 5.5 Special Types and Sentinels
# - 6 Data Transformation and Validation
#   - 6.1 Data Transformation Pipeline
#   - 6.2 PropertyInfo and Field Metadata
#   - 6.3 Type Coercion and Construction
#   - 6.4 Pydantic Compatibility Layer
#   - 6.5 File Extraction and Processing
# - 7 Advanced Features
#   - 7.1 Tool Calling and Integration
#   - 7.2 Streaming and Event Handling
#   - 7.3 Webhook Verification
#   - 7.4 Custom HTTP Clients and Proxies
# - 8 Development and Contribution
#   - 8.1 Development Environment Setup
#   - 8.2 Testing Framework and Practices
#   - 8.3 Code Quality and Type Checking
#   - 8.4 CI/CD Pipeline and Release Process
# - 9 Glossary
#
# 2) 핵심 모듈/컴포넌트(저장소의 핵심 역할)
# 다음은 저장소의 핵심 기능을 담당하는 대표적인 모듈군으로, 실제 구현 파일의 구체적인 이름은 버전에 따라 다를 수 있지만 역할은 대체로 아래와 같습니다.
#
# - OpenAI 및 AsyncOpenAI 클라이언트(3.1)
#   - 동기식 및 비동기식 API 호출을 추상화하는 진입점.
#   - 사용 예: openai.api_key 설정 후 openai.ChatCompletion.create(...) 같은 호출을 가능하게 함.
#   - 비동기 버전은 asyncio 기반의 호출 흐름을 제공합니다.
#
# - HTTP 클라이언트 기반 foundation(3.2)
#   - HTTP 요청/응답의 저수준 전송 계층.
#   - 요청 헤더 구성, 시간 초과, 재시도 정책(백오프), 인증 토큰 주입 등을 담당.
#   - 네트워크 설정(프록시, 타임아웃 등)과 연결 관리의 중심.
#
# - 요청(Request) 및 응답(Response) 처리(3.3)
#   - 직렬화/역직렬화 로직, API 응답의 파싱, 에러 코드 매핑.
#   - API 파이프라인에서 입력 데이터를 올바한 형식으로 변환하고, 응답을 사용하기 쉬운 파이딩 모델로 래핑.
#
# - 에러 처리 및 재시도 로직(3.4)
#   - API 호출 중 발생하는 다양한 예외를 정의하고 처리.
#   - 레이트 리밋, 네트워크 이슈 등에 대한 재시도 정책(지수 백오프 등)을 구현.
#
# - 페이징 처리(3.5)
#   - 페이지네이션이 필요한 엔드포인트의 결과를 순회할 수 있도록 도와주는 유틸리티/메커니즘.
#
# - 응답 래퍼(Response Wrappers)(3.6)
#   - API 응답을 타입-세이프한 모델로 래핑하고, 호출자에게 일관된 인터페이스 제공.
#   - 보조 메타데이터나 연관된 객체들을 함께 다룰 수 있게 해줌.
#
# - 인증 및 워크로드 식별(Authentication and Workload Identity)(3.7)
#   - API 키, Azure OpenAI 구성, 워크로드 아이덴티티 등 다양한 인증 방법을 지원.
#   - 보안 컨텍스트 관리와 자격 증명 프로바이더와의 인터페이스를 다룸.
#
# - API 리소스 모듈(4)
#   - Chat Completions, Embeddings, Fine-Tuning, Files, Audio/Images/Video, Realtime 등 각 API 엔드포인트를 다루는 “리소스 모듈”들.
#   - 예: Chat Completions 모듈은 대화형 엔드포인트의 파라미터(모델, 토큰 수, 온도 등)와 스트리밍 여부를 처리하고, 응답을 파싱하여 사용자가 쉽게 사용할 수 있는 형태로 반환.
#
# - 도구/고급 기능(7)
#   - Tool Calling, 스트리밍 이벤트 처리, 웹훅 검증, 사용자 정의 HTTP 클라이언트/프록시 등 고급 기능 지원.
#
# - 타입 시스템 및 데이터 타입(5)
#   - 타입 시스템 개요, 요청 파라미터 타입, 응답 모델, Pydantic(BaseModel 기반) 모델, 특수 타입/샌티넬 등.
#   - 개발 시 정적 타입 체크와 API 응답의 구조화를 돕는 역할.
#
# - 데이터 변환 및 검증(6)
#   - 데이터 변환 파이프라인, 필드 메타데이터(PropertyInfo), 타입 강제 변환(Type Coercion), Pydantic 호환 계층, 파일 추출/처리 로직.
#
# - 개발 및 기여(8)
#   - 개발 환경 구성, 테스트 프레임워크/관례, 코드 품질 및 타입 검사, CI/CD 파이프라인 및 릴리스 프로세스.
#
# 3) API 리소스/엔드포인트의 구조적 계층
# - 4 API Resources and Endpoints의 핵심 카테고리
#   - 4.1 Chat Completions API: 채팅형 대화 엔드포인트와 파라미터, 스트리밍 지원 및 응답 포맷
#   - 4.2 Responses API: 다중 모달 입력, 도구 연동, 대화 상태 관리
#   - 4.3 Assistants API (베타): 어시스턴트 구성, 쓰레드/메시지 관리, 실행 흐름, 스트리밍 이벤트
#   - 4.4 Fine-Tuning API: 파인튜닝 관련 엔드포인트
#   - 4.5 Embeddings: 임베딩 생성 및 관련 작업 흐름
#   - 4.6 Files: 파일 업로드 및 관리
#   - 4.7 Audio/Images/Video: 멀티모달 API
#   - 4.8 Additional API Resources: 기타 보조 엔드포인트
#   - 4.9 Realtime API (베타): 실시간 피드/스트리밍 관련 기능
# - 각 리소스 모듈은 공통적으로 공통 파라미터 구성, 요청/응답 모델, 관련 유틸리티를 공유하되, 엔드포인트 특성에 맞춘 로직으로 구성되어 있습니다.
#
# 4) 데이터 타입/검증 및 변환
# - 5 Data Types and Type System
#   - API 요청/응답의 타입 정의, Pydantic 모델 기반 구조화, 타입 시스템의 확장성 고려.
# - 6 Data Transformation and Validation
#   - 입력 데이터의 정합성 확보, 파이프라인으로의 데이터 변환, 파일 처리 및 특수 타입의 바인딩.
#
# 5) 개발/운용 측면
# - 8 Development and Contribution
#   - 개발 환경 설정, 테스트/타입 검사, 코드 품질 관리, CI/CD 및 릴리스 프로세스에 관한 안내.
# - 이 외에 문서화(Overview, Architecture, Installation 등)와 용어 해설(GLossary)도 포함되어 있습니다.
#
# 요약
# - 이 저장소의 핵심은 실사용자용 파이썬 클라이언트(API 래퍼)와 그 하부의 HTTP/에러/타입 시스템, 그리고 Chat Completions를 비롯한 모든 OpenAI API 리소스를 다루는 엔드포인트 모듈들로 구성됩니다.
# - 3장의 Core Client Classes에서 기본적인 호출 체인과 예외 처리, 페이징, 인증 등을 다루고, 4장의 API Resources에서 각 API 엔드포인트의 구체적 사용법과 파라미터를 제공합니다.
# - 5-6-7장에서는 타입 시스템, 데이터 검증/변환, 고급 기능(스트리밍, 도구 호출, 웹훅 등)을 다룹니다.
# - 8장은 개발 및 기여 방법에 관한 가이드입니다.
#
# 원하시면
# - 특정 모듈(예: Chat Completions, Embeddings, 스트리밍 처리)의 코드 구조를 더 자세히 요약해 드리거나,
# - 위키의 각 하위 페이지(예: 4.1.1 Parameters and Configuration)의 내용을 발췌해 더 구체적인 기능 설명으로 확장해 드리겠습니다.
# 또는 최신 파일 구조(저장소의 실제 파일/디렉토리 트리)에 맞춘 코드 수준의 맵을 원하시면 말씀해 주세요.

# %%
tool_list = []

for item in resp.output:
    if item.type == "mcp_list_tools":
        for tool in item.tools:
            tool_info = {
                "name": tool.name,
                "description": tool.description,
                "input_schema": tool.input_schema
            }
            tool_list.append(tool_info)

tool_list
# Out:
# [{'name': 'read_wiki_structure',
#   'description': 'Get a list of documentation topics for a GitHub repository.\n\nArgs:\n    repoName: GitHub repository in owner/repo format (e.g. "facebook/react")',
#   'input_schema': {'properties': {'repoName': {'type': 'string'}},
#    'required': ['repoName'],
#    'type': 'object'}},
#  {'name': 'read_wiki_contents',
#   'description': 'View documentation about a GitHub repository.\n\nArgs:\n    repoName: GitHub repository in owner/repo format (e.g. "facebook/react")',
#   'input_schema': {'properties': {'repoName': {'type': 'string'}},
#    'required': ['repoName'],
#    'type': 'object'}},
#  {'name': 'ask_question',
#   'description': 'Ask any question about a GitHub repository and get an AI-powered, context-grounded response.\n\nArgs:\n    repoName: GitHub repository or list of repositories (max 10) in owner/repo format\n    question: The question to ask about the repository',
#   'input_schema': {'properties': {'repoName': {'anyOf': [{'type': 'string'},
#       {'items': {'type': 'string'}, 'type': 'array'}]},
#     'question': {'type': 'string'}},
#    'required': ['repoName', 'question'],
#    'type': 'object'}}]

# %% [markdown]
# ---------------

# %% [markdown]
# ### 여러 도구들을 활용한 챗봇 구축
# - 여러 도구(웹검색, 파일검색, MCP)를 **하나의 요청에 함께 등록**하여 사용하는 방법을 보여줍니다.
# - 대화 히스토리를 **Python `list`로 직접 관리**합니다 (클라이언트 측 상태 관리).
#
# > **참고 — `230_Conversation_state.ipynb`와의 차이**
# > - **이 노트북**: `conversation_history` 리스트를 직접 누적하여 매 요청마다 전체 대화를 `input`으로 전달 → **수동 / 클라이언트 측** 상태 관리
# > - **230 노트북**: `previous_response_id`를 사용하여 OpenAI 서버가 상태를 자동 보존 → **서버 측** 상태 관리

# %%
tools = [
    {"type": "web_search"},
    {
        "type": "file_search",
        "vector_store_ids": [vector_store.id]
    },
    {
        "type": "mcp",
        "server_label": "deepwiki",
        "server_url": "https://mcp.deepwiki.com/mcp",
        "require_approval": "never",
    },
]

conversation_history = []

print("=== Tools 챗봇 (web_search, file_search, mcp) ===")
print("사용 가능한 도구: 웹검색, 파일검색(재무제표), DeepWiki")
print("종료하려면 'quit' 또는 'exit'를 입력하세요.\n")

while True:
    user_input = input("You: ")
    if user_input.strip().lower() in ["quit", "exit"]:
        print("챗봇을 종료합니다.")
        break

    conversation_history.append({
        "role": "user",
        "content": user_input
    })

    response = client.responses.create(
        model=Model,
        input=conversation_history,
        tools=tools,
    )

    assistant_message = response.output_text
    print(f"\nAssistant: {assistant_message}\n")

    conversation_history.append({
        "role": "assistant",
        "content": assistant_message
    })
# Out:
# === Tools 챗봇 (web_search, file_search, mcp) ===
# 사용 가능한 도구: 웹검색, 파일검색(재무제표), DeepWiki
# 종료하려면 'quit' 또는 'exit'를 입력하세요.
# You:  안녕 난 길동이야
# Assistant: 안녕하세요, 길동씨! 업로드하신 파일들을 확인해둘게요. 무엇을 도와드릴까요? 예를 들면:
#
# - 파일 내용 요약
# - 특정 키워드로 빠르게 검색
# - 중요한 포인트 추출 및 간단한 요약 표 만들기
# - 문서 간 비교/대조
# - 원문 번역(한국어 ↔ 영어)
# - 발표자료나 노트 형식으로 정리
#
# 원하시는 작업을 말씀해 주시면 바로 검색이나 요약을 시작하겠습니다. 예를 들어 “지난 분기 매출”이나 “계약서 조건 요약” 같은 키워드를 알려주셔도 되고, 그냥 일반적으로 파일들을 훑어보고 요약해 드려도 됩니다. 어떤 방식으로 도와드릴까요?
# You:  2022년 NAVER 의 ROE는 얼마인가요?
# Assistant: NAVER의 2022년 연간 ROE(Return on Equity)는 약 3.3%입니다. 여러 데이터 소스에서 2022-12-31 기준으로 3.29% ~ 3.34% 범위로 보고하고 있습니다. 예를 들어:
# - AlphaSquare: 2022년 ROE 3.29% ([alphasquare.co.kr](https://alphasquare.co.kr/home/financial-information?code=035420&utm_source=openai))
# - FNGuide: IFRS 연결 기준 2022년 ROE 약 3.3% ([comp.fnguide.com](https://comp.fnguide.com/SVO2/asp/SVD_FinanceRatio.asp?NewMenuID=104&gicode=A035420&utm_source=openai))
# - ValueInvesting: 2022-12-31 ROE 3.34% ([valueinvesting.io](https://valueinvesting.io/035420.KS/metric/roe?utm_source=openai))
#
# 참고로 ROE는 일반적으로 순이익을 자기자본으로 나눠 계산하는 지표이며, 연간 수치를 표기하는 방식이나 평균 자기자본의 사용 여부에 따라 약간의 차이가 날 수 있습니다. 필요하시면 NAVER의 2022 Integrated Report에서 공식 표를 확인해 드리거나, 특정 연도 정의(평균 자기자본 vs 연말 자기자본)로 재계산해 드리겠습니다.
# You:  quit
# 챗봇을 종료합니다.

# %% [markdown]
# ---------------
# ### Skills
# - **버전 관리된 스킬 번들**(`SKILL.md` + 보조 파일들의 폴더)을 OpenAI에 **업로드**하여 재사용
# - 스킬은 독립 도구가 아니라 **`shell` 도구의 실행 환경(`environment.skills`)에 부착**하여 사용
# - 동작 흐름: ① 스킬 폴더 업로드 → `skill_id` 획득 → ② shell 도구에 부착 → ③ 모델이 컨텍스트에서 스킬 이름·설명을 보고 필요 시 `SKILL.md`를 읽어 실행
#
# **(1) 스킬 번들 구조 예시**
# ```
# my_skill/
# ├── SKILL.md        # 메타데이터(name, description) + 모델용 지침
# └── script.py       # 보조 스크립트, API 명세, 리소스 등
# ```
#
# **(2) 스킬 업로드** — `POST https://api.openai.com/v1/skills`
# ```python
# import requests, os
#
# # 방법 A) 폴더 내 파일들을 멀티파트로 업로드
# resp = requests.post(
#     "https://api.openai.com/v1/skills",
#     headers={"Authorization": f"Bearer {os.getenv('OPENAI_API_KEY')}"},
#     files=[
#         ("files[]", ("SKILL.md", open("my_skill/SKILL.md", "rb"))),
#         ("files[]", ("script.py", open("my_skill/script.py", "rb"))),
#     ],
# )
# skill_id = resp.json()["id"]
# print(skill_id)
#
# # 방법 B) 단일 최상위 폴더를 압축한 zip 업로드
# # requests.post(url, headers=..., files={"files": ("skill.zip", open("skill.zip","rb"), "application/zip")})
# ```
#
# **(3) Responses API에서 사용** — `shell` 도구의 `environment.skills`에 부착
# ```python
# response = client.responses.create(
#     model=Model,
#     tools=[{
#         "type": "shell",
#         "environment": {
#             "type": "container_auto",
#             "skills": [
#                 {"type": "skill_reference", "skill_id": skill_id},
#                 # 특정 버전 고정도 가능: {"type": "skill_reference", "skill_id": skill_id, "version": 2}
#             ],
#         },
#     }],
#     input="업로드한 스킬을 사용하여 작업을 수행해 주세요."
# )
#
# print(response.output_text)
# ```
#
# > 참고: Skills는 `shell` 도구(호스팅 컨테이너 실행) 위에서 동작하므로, 이를 지원하는 모델과 계정 권한이 필요합니다. 위 코드는 개념 설명용 예시입니다.

# %% [markdown]
# #### 실습 예제: "투자 수익률(ROI) 분석 스킬"
#
# 스킬의 개념을 직관적으로 이해하기 위해, 간단하지만 실용적인 스킬을 직접 업로드해 사용해 봅니다.
#
# **왜 스킬인가?** — 다음 두 가지를 한 번 패키지로 묶어 두면, 매번 긴 지침을 반복해서 붙여넣을 필요가 없습니다.
# 1. **표준 리포트 형식** (`SKILL.md`의 지침) → 매번 같은 양식으로 결과 정리
# 2. **정확한 계산** (`roi_calculator.py` 스크립트) → LLM이 약한 수치 계산을 스크립트가 대신 처리
#
# **스킬 번들 구성** (`skills/roi_report/` 폴더):
# ```
# skills/roi_report/
# ├── SKILL.md           # 스킬 이름·설명 + 출력 형식 + "계산은 스크립트로" 지침
# └── roi_calculator.py  # 원금/현재가/기간 → 총수익률, 연환산수익률(CAGR) 계산
# ```
#
# **동작 흐름**: 스킬 업로드(`skill_id` 획득) → `shell` 도구에 부착 → 사용자가 투자 정보를 물으면, 모델이 스킬 설명을 보고 `roi_calculator.py`를 실행한 뒤 표준 리포트 형식으로 답변.

# %%
import os
import requests

# (1) 스킬 번들 업로드 : skills/roi_report 폴더의 파일들을 멀티파트로 전송
#     성공하면 skill_id 를 돌려받아 이후 요청에서 재사용한다.
#     주의) 모든 파일은 "하나의 최상위 폴더" 아래에 있어야 하므로
#           파일명 앞에 공통 폴더명(roi_report/)을 붙여서 전송한다.
skill_dir = "skills/roi_report"
top_level = "roi_report"  # 업로드 번들의 최상위 폴더명
files = [
    ("files[]", (f"{top_level}/SKILL.md", open(f"{skill_dir}/SKILL.md", "rb"))),
    ("files[]", (f"{top_level}/roi_calculator.py", open(f"{skill_dir}/roi_calculator.py", "rb"))),
]

upload = requests.post(
    "https://api.openai.com/v1/skills",
    headers={"Authorization": f"Bearer {os.getenv('OPENAI_API_KEY')}"},
    files=files,
)

print(upload.status_code)
print(upload.json())

skill_id = upload.json()["id"]
print("업로드된 skill_id:", skill_id)
# Out:
# 200
# {'id': 'skill_6a2a216b6c508198bb8ab325836c8fd50a1f058d663369a7', 'object': 'skill', 'created_at': 1781145963, 'default_version': '1', 'description': '투자 원금, 현재 평가액, 투자 기간을 바탕으로 투자 수익률(ROI)과 연환산수익률(CAGR)을 계산하고 표준 리포트 형식으로 정리할 때 사용합니다.', 'latest_version': '1', 'name': 'roi-report'}
# 업로드된 skill_id: skill_6a2a216b6c508198bb8ab325836c8fd50a1f058d663369a7

# %%
# (2) 업로드한 스킬을 shell 도구에 부착하여 사용
#     모델이 질문을 보고 스스로 roi_calculator.py 를 실행한 뒤 표준 리포트로 답변한다.
#
#     주의) shell 도구의 environment(컨테이너 + Skills)는 gpt-5.2 이상에서만 지원된다.
#           (gpt-5-nano, gpt-5.1 등에서는 사용 불가)
SkillModel = "gpt-5.2"

response = client.responses.create(
    model=SkillModel,
    tools=[{
        "type": "shell",
        "environment": {
            "type": "container_auto",
            "skills": [
                {"type": "skill_reference", "skill_id": skill_id},
            ],
        },
    }],
    input="3년 전 1,000만원을 투자했는데 지금 1,728만원이 되었습니다. 수익률을 분석해 주세요.",
)

print(response.output_text)
# Out:
# roi-report 스킬을 사용해 ROI(총수익률)와 CAGR(연환산수익률)을 계산해 리포트로 정리합니다.
#
# ### 투자 수익률 분석 리포트
# - 투자 원금: 10,000,000원
# - 현재 평가액: 17,280,000원
# - 투자 기간: 3년
#
# | 지표 | 값 |
# |---|---|
# | 총수익 | 7,280,000원 |
# | 총수익률 | 72.80% |
# | 연환산수익률(CAGR) | 20.00% |
#
# ### 종합 평가
# 연환산수익률(CAGR) 20.00%로 **우수** 수준입니다.

# %% [markdown]
# ---------------
# ### Shell
# - 호스팅 컨테이너 또는 로컬 런타임에서 쉘(shell) 명령을 실행
# - 모델이 파일 조작, 스크립트 실행, 시스템 명령 수행 등 터미널 작업을 직접 처리
# - 코드 실행이나 환경 조작이 필요한 에이전틱 작업에 활용
#
# > 주의: shell 도구와 컨테이너 실행 환경(`environment`)은 **gpt-5.2 이상**에서만 동작합니다. 아래 셀은 이를 지원하는 모델로 실제 실행해 보는 예제입니다.

# %%
# shell 도구로 컨테이너 안에서 쉘 명령을 실행시키는 예제
#   - environment(container_auto)를 주면 모델이 격리된 컨테이너에서 명령을 실행한다.
#   - gpt-5.2 이상 필요 (gpt-5-nano, gpt-5.1 미지원)
#
#   포인트) "1+...+100" 같은 질문은 모델이 암산으로도 답할 수 있어 shell 사용을 증명하지 못한다.
#           그래서 "실제 컨테이너에서 명령을 실행해야만 알 수 있는 것"(OS/파이썬 버전 등)을 물어본다.
ShellModel = "gpt-5.2"

response = client.responses.create(
    model=ShellModel,
    tools=[{
        "type": "shell",
        "environment": {"type": "container_auto"},
    }],
    input=(
        "셸 명령으로 다음을 직접 확인해서 알려줘. "
        "(1) uname -a 로 운영체제 정보, "
        "(2) python --version 으로 파이썬 버전, "
        "(3) pip list 로 설치된 패키지 개수."
    ),
)

print(response.output_text)

# 모델이 실제로 shell 명령을 실행했는지 출력 항목의 타입으로 확인
#   (shell 관련 항목이 보이면 컨테이너에서 명령이 실제 실행된 것)
print("\n--- response.output 항목 타입 ---")
for item in response.output:
    print("-", item.type)
# Out:
# 1) `uname -a` (운영체제 정보)
# - `Linux 6f5097ed4121 4.4.0 #1 SMP Sun Jan 10 15:06:54 PST 2016 x86_64 GNU/Linux`
#
# 2) `python --version` (파이썬 버전)
# - `Python 3.13.5`
#
# 3) `pip list` (설치된 패키지 개수)
# - `427` 개
#
# --- response.output 항목 타입 ---
# - shell_call
# - shell_call_output
# - message

# %% [markdown]
# ---------------
# ### Tool search
# - 사용 가능한 도구가 많을 때, 관련 도구를 동적으로 로드하여 토큰 사용량 및 지연시간(latency)을 최적화
# - 모든 도구 정의를 매 요청마다 모델에 전달하는 대신, 요청과 관련된 도구만 선별하여 컨텍스트에 포함
# - 대규모 도구 집합(특히 여러 MCP 서버 연결)을 다룰 때 효율성을 크게 향상
#
# **사용법**
# - `tools`에 `{"type": "tool_search"}`를 추가하고, 지연 로드할 도구(MCP 서버 등)에는 `defer_loading: True`를 지정
# - `tool_search`는 **gpt-5.4 이상**에서만 동작
#
# **효과 확인 방법**
# - 같은 질문을 ① 모든 도구 선(先)로드 vs ② `tool_search` 지연 로드로 보내고 **입력 토큰 수(`response.usage.input_tokens`)를 비교**
# - `response.output`에 `tool_search_call` 항목이 나타나면 모델이 도구를 동적으로 검색·로드한 것
#
# > 참고: 토큰 절감 효과는 **등록한 도구(함수) 수가 많을수록 커집니다.** 아래 예제는 DeepWiki MCP(도구 3개)라 절감폭이 작을 수 있지만, 동작 원리와 측정 방법을 확인하는 데 목적이 있습니다.

# %%
# Tool search 효과 비교 : 같은 질문을 (A) 모든 도구 선로드 vs (B) tool_search 지연로드 로 보내고
#                          입력 토큰 수를 비교한다. (tool_search 는 gpt-5.4 이상 필요)
ToolSearchModel = "gpt-5.5"

question = "DeepWiki로 공개 GitHub 저장소에 대해 어떤 것들을 물어볼 수 있어?"

# tool_search 방식 : defer_loading=True 로 도구를 지연 로드하고, 필요할 때만 검색해서 로드
resp_search = client.responses.create(
    model=ToolSearchModel,
    tools=[
        {
            "type": "mcp",
            "server_label": "deepwiki",
            "server_url": "https://mcp.deepwiki.com/mcp",
            "require_approval": "never",
            "defer_loading": True,
        },
        {"type": "tool_search"},
    ],
    input=question,
)

# tool_search 가 실제로 작동했는지 출력 항목 타입으로 확인 --> tool_search_call 이 보이면 동적 로드 작동
for item in resp_search.output:
    print("-", item.type)
# Out:
# - mcp_list_tools
# - reasoning
# - tool_search_call
# - tool_search_output
# - message

# %%
resp_search.output_text
# Out:
# 'DeepWiki로 **공개 GitHub 저장소**에 대해 꽤 다양한 질문을 할 수 있어요. 저장소를 `owner/repo` 형식, 예를 들어 `facebook/react`, `vercel/next.js`처럼 지정하면 됩니다.\n\n물어볼 수 있는 것들은 대략 이런 범주입니다.\n\n## 1. 저장소 개요\n\n예시 질문:\n\n- “이 저장소는 무엇을 하는 프로젝트야?”\n- “주요 기능을 요약해줘.”\n- “이 프로젝트의 아키텍처를 설명해줘.”\n- “초보자가 이해해야 할 핵심 개념은 뭐야?”\n\n## 2. 코드 구조와 디렉터리 설명\n\n예시 질문:\n\n- “디렉터리 구조를 설명해줘.”\n- `src` 폴더에는 어떤 코드가 있어?”\n- “주요 모듈들이 어떻게 나뉘어 있어?”\n- “엔트리포인트는 어디야?”\n\n## 3. 특정 기능의 구현 방식\n\n예시 질문:\n\n- “라우팅은 어떻게 구현되어 있어?”\n- “인증 로직은 어디에 있고 어떻게 동작해?”\n- “캐싱 시스템은 어떻게 설계되어 있어?”\n- “플러그인 구조가 있다면 설명해줘.”\n\n## 4. 특정 파일 또는 클래스/함수 설명\n\n예시 질문:\n\n- “`packages/foo/src/bar.ts` 파일의 역할을 설명해줘.”\n- “`createClient` 함수가 하는 일을 알려줘.”\n- “이 클래스의 책임과 사용 흐름을 설명해줘.”\n- “이 함수가 호출되는 경로를 추적해줘.”\n\n## 5. 데이터 흐름 / 실행 흐름 분석\n\n예시 질문:\n\n- “요청이 들어왔을 때 처리 흐름을 단계별로 설명해줘.”\n- “CLI 명령어가 실행될 때 내부적으로 어떤 일이 일어나?”\n- “빌드 과정의 흐름을 설명해줘.”\n- “상태 관리 흐름을 설명해줘.”\n\n## 6. 설치, 빌드, 실행 방법\n\n예시 질문:\n\n- “이 프로젝트를 로컬에서 실행하려면 어떻게 해야 해?”\n- “개발 환경 설정 방법을 알려줘.”\n- “테스트는 어떻게 실행해?”\n- “빌드 명령어와 배포 과정은 어떻게 돼?”\n\n## 7. API, 설정, 사용법\n\n예시 질문:\n\n- “이 라이브러리의 기본 사용법을 알려줘.”\n- “주요 public API를 정리해줘.”\n- “설정 파일 옵션들을 설명해줘.”\n- “간단한 사용 예제를 만들어줘.”\n\n## 8. 기여자 관점의 질문\n\n예시 질문:\n\n- “처음 기여하려면 어디부터 보면 좋아?”\n- “좋은 first issue를 찾기 전에 이해해야 할 구조는?”\n- “새 기능을 추가하려면 어떤 파일들을 수정해야 할까?”\n- “테스트를 추가하려면 어디에 넣어야 해?”\n\n## 9. 코드 품질, 설계, 의존성 분석\n\n예시 질문:\n\n- “이 프로젝트의 주요 의존성은 뭐야?”\n- “아키텍처상 중요한 설계 결정은 뭐야?”\n- “확장 포인트는 어디야?”\n- “잠재적으로 복잡하거나 중요한 모듈을 알려줘.”\n\n## 10. 여러 저장소 비교\n\nDeepWiki는 최대 10개 저장소까지 질문할 수 있으므로 비교도 가능합니다.\n\n예시 질문:\n\n- “`facebook/react`와 `preactjs/preact`의 구조적 차이를 설명해줘.”\n- “이 두 저장소의 라우팅 처리 방식 차이를 비교해줘.”\n- “각 프로젝트의 빌드 시스템을 비교해줘.”\n\n## 11. 문서 주제 확인\n\n저장소에 대해 DeepWiki가 정리한 문서 주제 목록을 볼 수도 있습니다.\n\n예시:\n\n- “이 저장소에서 볼 수 있는 문서 주제 목록을 알려줘.”\n- “DeepWiki에 정리된 섹션들을 보여줘.”\n\n---\n\n예를 들어 이렇게 요청하면 됩니다:\n\n> `vercel/next.js` 저장소에서 App Router가 내부적으로 어떻게 동작하는지 설명해줘.\n\n또는:\n\n> `facebook/react` 저장소의 reconciler 구조를 초보자도 이해할 수 있게 설명해줘.\n\n한마디로 DeepWiki는 공개 GitHub 저장소에 대해 **코드베이스 탐색, 구조 설명, 특정 기능 분석, 실행 흐름 추적, 사용법 정리, 저장소 간 비교** 같은 질문에 특히 유용합니다.'
