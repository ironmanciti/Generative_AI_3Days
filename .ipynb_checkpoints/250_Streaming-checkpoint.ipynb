# %% [markdown]
# # 스트리밍 API 응답
# 기본적으로 OpenAI API에 요청을 보내면 모델의 전체 출력을 생성한 후 단일 HTTP 응답으로 다시 전송합니다. 긴 출력을 생성할 경우 응답을 기다리는 데 시간이 걸릴 수 있습니다.
# 스트리밍 응답을 사용하면 전체 응답을 생성하는 동안 모델 출력의 시작 부분을 인쇄하거나 처리할 수 있습니다.
#
# 응답 스트리밍을 시작하려면 stream=True응답 엔드포인트에 대한 요청을 설정합니다.

# %%
from dotenv import load_dotenv
load_dotenv() # read local .env file
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

Model = "gpt-5-nano"

# %%
stream = client.responses.create(
    model=Model,  
    input=[
        {
            "role": "user",
            "content": "성경의 창세기 시작 부분을 1000 글자내에서 알려줘.",  # 사용자 입력 프롬프트
        },
    ],
    stream=True,     # 스트리밍 응답 활성화 (조각 단위로 응답 받기)
)

# 응답이 조각(chunk) 단위로 도착할 때마다 출력
for chunk in stream:
    if chunk.type == 'response.output_text.delta':  # 응답 조각이 텍스트 델타(추가분)인 경우만 처리
        print(chunk.delta, end="")       # 출력된 텍스트 델타를 이어서 출력 (줄바꿈 없이)
# Out:
# 창세기의 시작은 무에서 만물을 창조하시는 하나님으로 열립니다. 창세기 1–2장은 6일에 걸친 창조와 안식을 다루고, 하나님은 빛과 어둠을 나누시고, 하늘과 땅을 구분하시며, 바다와 땅을 채우실 생물을 준비하십니다. 이어 해와 달과 별들을 만드시고, 바다의 물고기와 공중의 새, 땅의 짐승까지 차례로 창조하신 뒤, 하나님의 형상대로 남자와 여자를 만드시고 그들에게 땅을 다스리며 모든 나무의 열매를 먹으라 축복하십니다. 다만 선악과의 열매만 먹지 말라 명하셨습니다. 그러나 뱀의 유혹으로 여자와 남자가 그 열매를 먹자, 눈이 밝아져 자기들이 벗은 것을 깨닫고 부끄러워합니다. 하나님은 불순종을 지적하시고 뱀에게 저주를 선언하며 여자와 남자에게 고통과 노동, 죽음의 그림자를 예고하십니다. 또한 에덴에서 쫓겨나게 하시고 생명의 나무에 이르는 길은 천사들과 불타는 칼로 막으십니다. 이로써 창세기 시작은 창조의 기쁨과 타락의 시작, 인간과 하나님 사이의 관계가 깨지는 이야기를 보여줍니다.
#
# 필요하시다면 이 초반의 내용을 공개 도메인(KJV) 번역의 실제 구절로도 제공해 드릴 수 있습니다. 원하시는가요?
