# %% [markdown]
# ### Reasoning (추론)
#
# GPT-5와 같은 추론 모델은 강화 학습을 통해 추론을 수행하도록 훈련된 LLM입니다. 추론 모델은 사용자에게 응답하기 전에 먼저 생각하여 , 사용자에게 응답하기 전에 긴 내부 사고 사슬을 생성합니다. 추론 모델은 복잡한 문제 해결, 코딩, 과학적 추론, 그리고 에이전트 워크플로우를 위한 다단계 계획 수립에 탁월합니다. 또한 , 경량 코딩 에이전트인 Codex CLI 에 가장 적합한 모델입니다.
#
# 추론 모델은 입력 및 출력 토큰 외에도 추론 토큰을 도입합니다 . 모델은 이러한 추론 토큰을 사용하여 "사고"하고, 제시된 질문을 분석하며, 다양한 접근 방식을 고려하여 최적의 응답을 생성합니다. 추론 토큰을 생성한 후, 모델은 완성 토큰 형태로 응답을 출력하고, 추론 토큰은 컨텍스트에서 제거합니다.
#
# 다음은 사용자와 어시스턴트 간의 여러 단계로 이루어진 대화 예시입니다. 각 단계의 입력 및 출력 토큰은 다음 단계로 전달되지만, 추론 토큰은 버려집니다.

# %%
from dotenv import load_dotenv
load_dotenv() # read local .env file
# Out:
# True

# %%
from openai import OpenAI
import json

client = OpenAI()

Model = "gpt-5"

# %%
prompt = """
문자열로 표현된 행렬을 '[1,2],[3,4],[5,6]' 형식으로 받아서 같은 형식으로 전치행렬을 출력하는 파이썬 스크립트를 작성하세요.
"""

response = client.responses.create(
    model=Model,  
    reasoning={"effort": "medium"},  # 추론 수준 설정: 중간 수준의 정답 생성 요구
    input=[
        {
            "role": "user", 
            "content": prompt  # 사용자의 질문 또는 지시
        }
    ]
)

# 생성된 파이썬 스크립트 응답 출력
print(response.output_text)
# Out:
# 다음은 '[1,2],[3,4],[5,6]' 형식의 문자열을 입력받아 같은 형식으로 전치행렬을 출력하는 파이썬 스크립트입니다.
#
# #!/usr/bin/env python3
# import sys, ast
#
# def parse_matrix(s):
#     try:
#         data = ast.literal_eval("[" + s + "]")
#     except (SyntaxError, ValueError):
#         raise ValueError("입력 형식이 올바르지 않습니다. 예: [1,2],[3,4]")
#     if not isinstance(data, list) or not data:
#         raise ValueError("행렬이 비어있습니다.")
#     rows = []
#     for row in data:
#         if not isinstance(row, (list, tuple)):
#             raise ValueError("각 행은 대괄호로 묶인 리스트여야 합니다. 예: [1,2]")
#         rows.append(list(row))
#     n = len(rows[0])
#     if any(len(r) != n for r in rows):
#         raise ValueError("모든 행의 길이가 같아야 합니다.")
#     return rows
#
# def transpose(mat):
#     if not mat or not mat[0]:
#         return []
#     return [list(col) for col in zip(*mat)]
#
# def format_matrix(mat):
#     return ",".join("[" + ",".join(str(v) for v in row) + "]" for row in mat)
#
# def main():
#     if len(sys.argv) > 1:
#         s = " ".join(sys.argv[1:]).strip()
#     else:
#         s = sys.stdin.read().strip() or (input().strip() if not sys.stdin.isatty() else "")
#         if not s:
#             try:
#                 s = input().strip()
#             except EOFError:
#                 s = ""
#     if not s:
#         print("입력이 비어있습니다. 예: [1,2],[3,4]", file=sys.stderr)
#         sys.exit(1)
#     try:
#         mat = parse_matrix(s)
#         t = transpose(mat)
#         print(format_matrix(t))
#     except ValueError as e:
#         print(str(e), file=sys.stderr)
#         sys.exit(1)
#
# if __name__ == "__main__":
#     main()
#
# 사용 예
# - 입력: [1,2],[3,4],[5,6]
# - 출력: [1,3,5],[2,4,6]
#
# 표준입력으로 받거나 명령행 인자로 문자열을 넘길 수 있습니다.
# 예: echo "[1,2],[3,4]" | python script.py
# 예: python script.py "[1,2],[3,4]"

# %%
response.output
# Out:
# [ResponseReasoningItem(id='rs_074ea72dca4a6a360069af9256a1448194bdb8e0ea0c0a1fa1', summary=[], type='reasoning', content=None, encrypted_content=None, status=None),
#  ResponseOutputMessage(id='msg_074ea72dca4a6a360069af92a5fda081949fd160ad35ef2b20', content=[ResponseOutputText(annotations=[], text='다음은 \'[1,2],[3,4],[5,6]\' 형식의 문자열을 입력받아 같은 형식으로 전치행렬을 출력하는 파이썬 스크립트입니다.\n\n#!/usr/bin/env python3\nimport sys, ast\n\ndef parse_matrix(s):\n    try:\n        data = ast.literal_eval("[" + s + "]")\n    except (SyntaxError, ValueError):\n        raise ValueError("입력 형식이 올바르지 않습니다. 예: [1,2],[3,4]")\n    if not isinstance(data, list) or not data:\n        raise ValueError("행렬이 비어있습니다.")\n    rows = []\n    for row in data:\n        if not isinstance(row, (list, tuple)):\n            raise ValueError("각 행은 대괄호로 묶인 리스트여야 합니다. 예: [1,2]")\n        rows.append(list(row))\n    n = len(rows[0])\n    if any(len(r) != n for r in rows):\n        raise ValueError("모든 행의 길이가 같아야 합니다.")\n    return rows\n\ndef transpose(mat):\n    if not mat or not mat[0]:\n        return []\n    return [list(col) for col in zip(*mat)]\n\ndef format_matrix(mat):\n    return ",".join("[" + ",".join(str(v) for v in row) + "]" for row in mat)\n\ndef main():\n    if len(sys.argv) > 1:\n        s = " ".join(sys.argv[1:]).strip()\n    else:\n        s = sys.stdin.read().strip() or (input().strip() if not sys.stdin.isatty() else "")\n        if not s:\n            try:\n                s = input().strip()\n            except EOFError:\n                s = ""\n    if not s:\n        print("입력이 비어있습니다. 예: [1,2],[3,4]", file=sys.stderr)\n        sys.exit(1)\n    try:\n        mat = parse_matrix(s)\n        t = transpose(mat)\n        print(format_matrix(t))\n    except ValueError as e:\n        print(str(e), file=sys.stderr)\n        sys.exit(1)\n\nif __name__ == "__main__":\n    main()\n\n사용 예\n- 입력: [1,2],[3,4],[5,6]\n- 출력: [1,3,5],[2,4,6]\n\n표준입력으로 받거나 명령행 인자로 문자열을 넘길 수 있습니다.\n예: echo "[1,2],[3,4]" | python script.py\n예: python script.py "[1,2],[3,4]"', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')]

# %% [markdown]
# ### Python 프로젝트 계획 및 생성

# %%
prompt = """
사용자 질문을 받아 답변과 매핑된 데이터베이스에서 검색하는 Python 앱을 만들고 싶습니다.
유사한 답변이 있으면 일치하는 답변을 검색합니다.
만약 일치하지 않으면 사용자에게 답변을 입력하도록 요청하고
질문/답변 쌍을 데이터베이스에 저장합니다. 필요한 디렉터리 구조를 계획한 후
각 파일을 전체적으로 반환합니다.
코드 전체가 아닌 시작과 끝에만 해설을 제공하세요.
한국어로 답하세요.
"""

response = client.responses.create(
    model=Model,
    input=[
        {
            "role": "user",
            "content": prompt,
        }
    ]
)

print(response.output_text)
# Out:
# 아래는 간단한 CLI 기반 Python 앱의 설계와 전체 코드입니다. 동작 요약:
# - SQLite 데이터베이스에 질문/답변(Q/A) 쌍을 저장합니다.
# - 사용자가 질문을 입력하면 저장된 질문들과의 유사도를 계산해 가장 비슷한 질문을 찾습니다.
# - 임계치 이상이면 해당 답변을 반환합니다.
# - 임계치 미만이면 사용자에게 답변을 입력받아 Q/A를 저장합니다.
# - 외부 라이브러리 없이 표준 라이브러리만 사용합니다.
#
# 디렉터리 구조
# - app.py
# - README.md
# - requirements.txt
# - db/
#   - __init__.py
#   - database.py
#   - schema.sql
# - services/
#   - __init__.py
#   - qa_service.py
#   - similarity.py
# - utils/
#   - __init__.py
#   - text.py
# - data/ (런타임에 DB 파일 생성)
#
# 파일 전체
#
# 파일: app.py
# ```
# #!/usr/bin/env python3
# # -*- coding: utf-8 -*-
#
# import sys
# import signal
# from db.database import Database
# from services.qa_service import QAService
#
# def _graceful_exit(signum, frame):
#     print("\n종료합니다.")
#     sys.exit(0)
#
# def main():
#     signal.signal(signal.SIGINT, _graceful_exit)
#     signal.signal(signal.SIGTERM, _graceful_exit)
#
#     db = Database(db_path="data/qa.sqlite")
#     db.init_db()
#
#     service = QAService(db=db, similarity_threshold=0.82)
#
#     print("Q/A 매핑 CLI입니다. 질문을 입력하세요. (종료: q 또는 빈 줄)")
#     while True:
#         try:
#             question = input("\n질문> ").strip()
#         except EOFError:
#             print("\n종료합니다.")
#             break
#
#         if question.lower() == "q" or question == "":
#             print("종료합니다.")
#             break
#
#         match = service.find_similar(question)
#         if match is not None:
#             matched_id, matched_q, score = match
#             answer = service.get_answer(matched_id)
#             print(f"\n[매칭된 질문] {matched_q}")
#             print(f"[유사도] {score:.2%}")
#             print(f"[답변]\n{answer}")
#             continue
#
#         print("유사한 질문이 없습니다.")
#         answer = input("이 질문의 답변을 입력해 주세요: ").strip()
#         if answer == "":
#             print("빈 답변은 저장하지 않습니다.")
#             continue
#
#         saved_id = service.add_qa(question, answer)
#         print(f"저장되었습니다. (id={saved_id})")
#
# if __name__ == "__main__":
#     main()
# ```
#
# 파일: README.md
# ```
# # Q/A 매핑 Python 앱 (CLI)
#
# 이 앱은 사용자의 질문을 받아 기존 데이터베이스에서 유사한 질문을 검색하고, 유사한 질문이 없으면 사용자의 답변을 입력받아 새 Q/A를 저장합니다.
#
# ## 특징
# - SQLite 기반 로컬 DB (`data/qa.sqlite`)
# - 표준 라이브러리만 사용 (추가 의존성 없음)
# - 간단한 유사도 계산(문장 유사도 + 토큰 Jaccard)과 임계치 기반 매칭
#
# ## 설치 및 실행
# 1. Python 3.8 이상을 권장합니다.
# 2. (선택) 가상환경 생성
#    - macOS/Linux:
#      ```bash
#      python3 -m venv .venv
#      source .venv/bin/activate
#      ```
#    - Windows (PowerShell):
#      ```powershell
#      python -m venv .venv
#      .\.venv\Scripts\Activate.ps1
#      ```
# 3. 의존성 설치
#    ```bash
#    pip install -r requirements.txt
#    ```
# 4. 실행
#    ```bash
#    python app.py
#    ```
#
# ## 사용법
# - 프롬프트에 질문을 입력하면 기존 질문들과의 유사도를 계산해 가장 비슷한 질문을 찾습니다.
# - 유사한 질문이 임계치(기본 0.82) 이상이면 해당 답변을 표시합니다.
# - 없으면 답변을 입력하라는 메시지가 나오며, 입력 시 데이터베이스에 저장됩니다.
# - 종료하려면 빈 줄 또는 `q` 입력.
#
# ## 데이터베이스
# - 파일: `data/qa.sqlite`
# - 테이블: `qa_pairs(id, question, answer, created_at, updated_at)`
#
# ## 참고
# - 유사도는 `difflib.SequenceMatcher` 기반 문자 유사도와 토큰 단위 Jaccard 유사도의 가중 평균으로 계산합니다.
# - ON CONFLICT(UNIQUE question)에 대해 자동 업데이트합니다(가능한 경우). 환경에 따라 구버전 SQLite에서는 REPLACE 전략으로 대체됩니다.
# ```
#
# 파일: requirements.txt
# ```
# # 표준 라이브러리만 사용합니다. 외부 의존성 없음.
# ```
#
# 파일: db/__init__.py
# ```
# # 패키지 초기화 파일 (비워둠)
# ```
#
# 파일: db/database.py
# ```
# # -*- coding: utf-8 -*-
# import os
# import sqlite3
# from contextlib import contextmanager
#
# SCHEMA_PATH = os.path.join(os.path.dirname(__file__), "schema.sql")
#
# class Database:
#     def __init__(self, db_path="data/qa.sqlite"):
#         self.db_path = db_path
#         self._ensure_dir()
#
#     def _ensure_dir(self):
#         directory = os.path.dirname(self.db_path)
#         if directory and not os.path.exists(directory):
#             os.makedirs(directory, exist_ok=True)
#
#     @contextmanager
#     def connect(self):
#         conn = sqlite3.connect(self.db_path)
#         try:
#             conn.row_factory = sqlite3.Row
#             conn.execute("PRAGMA foreign_keys = ON;")
#             conn.execute("PRAGMA journal_mode = WAL;")
#             yield conn
#             conn.commit()
#         finally:
#             conn.close()
#
#     def init_db(self):
#         with open(SCHEMA_PATH, "r", encoding="utf-8") as f:
#             schema_sql = f.read()
#         with self.connect() as conn:
#             conn.executescript(schema_sql)
#
#     def fetch_all_questions(self):
#         with self.connect() as conn:
#             cur = conn.execute("SELECT id, question FROM qa_pairs ORDER BY id ASC;")
#             rows = cur.fetchall()
#             return [(row["id"], row["question"]) for row in rows]
#
#     def fetch_answer_by_id(self, qa_id: int):
#         with self.connect() as conn:
#             cur = conn.execute("SELECT answer FROM qa_pairs WHERE id = ?;", (qa_id,))
#             row = cur.fetchone()
#             return row["answer"] if row else None
#
#     def insert_or_update_qa(self, question: str, answer: str):
#         with self.connect() as conn:
#             try:
#                 # SQLite 3.24+ 지원: ON CONFLICT ... DO UPDATE
#                 cur = conn.execute(
#                     """
#                     INSERT INTO qa_pairs (question, answer)
#                     VALUES (?, ?)
#                     ON CONFLICT(question) DO UPDATE SET
#                         answer = excluded.answer,
#                         updated_at = CURRENT_TIMESTAMP;
#                     """,
#                     (question, answer),
#                 )
#             except sqlite3.OperationalError:
#                 # 구버전 SQLite 대체: REPLACE (기존 행을 삭제 후 새로 삽입)
#                 cur = conn.execute(
#                     """
#                     INSERT OR REPLACE INTO qa_pairs (id, question, answer, created_at, updated_at)
#                     VALUES (
#                         (SELECT id FROM qa_pairs WHERE question = ?),
#                         ?, ?,
#                         COALESCE((SELECT created_at FROM qa_pairs WHERE question = ?), CURRENT_TIMESTAMP),
#                         CURRENT_TIMESTAMP
#                     );
#                     """,
#                     (question, question, answer, question),
#                 )
#             # 마지막 삽입/업데이트된 id 구하기
#             # lastrowid는 UPDATE일 때 None일 수 있으므로 다시 조회
#             qa_id = cur.lastrowid
#             if not qa_id:
#                 cur2 = conn.execute("SELECT id FROM qa_pairs WHERE question = ?;", (question,))
#                 row = cur2.fetchone()
#                 qa_id = row["id"] if row else None
#             return qa_id
# ```
#
# 파일: db/schema.sql
# ```
# PRAGMA foreign_keys = ON;
#
# CREATE TABLE IF NOT EXISTS qa_pairs (
#     id INTEGER PRIMARY KEY AUTOINCREMENT,
#     question TEXT NOT NULL UNIQUE,
#     answer   TEXT NOT NULL,
#     created_at DATETIME NOT NULL DEFAULT CURRENT_TIMESTAMP,
#     updated_at DATETIME NOT NULL DEFAULT CURRENT_TIMESTAMP
# );
#
# CREATE INDEX IF NOT EXISTS idx_qa_pairs_question ON qa_pairs(question);
# ```
#
# 파일: services/__init__.py
# ```
# # 패키지 초기화 파일 (비워둠)
# ```
#
# 파일: services/qa_service.py
# ```
# # -*- coding: utf-8 -*-
# from typing import Optional, Tuple
# from db.database import Database
# from services.similarity import best_match
#
# class QAService:
#     def __init__(self, db: Database, similarity_threshold: float = 0.82):
#         self.db = db
#         self.threshold = similarity_threshold
#
#     def find_similar(self, question: str) -> Optional[Tuple[int, str, float]]:
#         """
#         반환: (matched_id, matched_question, score) 또는 None
#         """
#         candidates = self.db.fetch_all_questions()
#         if not candidates:
#             return None
#         return best_match(question, candidates, threshold=self.threshold)
#
#     def get_answer(self, qa_id: int) -> Optional[str]:
#         return self.db.fetch_answer_by_id(qa_id)
#
#     def add_qa(self, question: str, answer: str) -> int:
#         return self.db.insert_or_update_qa(question, answer)
# ```
#
# 파일: services/similarity.py
# ```
# # -*- coding: utf-8 -*-
# from typing import Iterable, List, Tuple, Optional
# from difflib import SequenceMatcher
# from utils.text import normalize, tokenize
#
# def char_similarity(a: str, b: str) -> float:
#     """
#     문자 단위 유사도 (SequenceMatcher)
#     """
#     a_n = normalize(a)
#     b_n = normalize(b)
#     if not a_n or not b_n:
#         return 0.0
#     return SequenceMatcher(None, a_n, b_n).ratio()
#
# def jaccard_token_similarity(a: str, b: str) -> float:
#     """
#     토큰 Jaccard 유사도
#     """
#     ta = set(tokenize(a))
#     tb = set(tokenize(b))
#     if not ta and not tb:
#         return 1.0
#     if not ta or not tb:
#         return 0.0
#     inter = len(ta & tb)
#     union = len(ta | tb)
#     return inter / union if union else 0.0
#
# def combined_similarity(a: str, b: str, w_char: float = 0.6, w_jaccard: float = 0.4) -> float:
#     c = char_similarity(a, b)
#     j = jaccard_token_similarity(a, b)
#     return w_char * c + w_jaccard * j
#
# def best_match(
#     query: str,
#     candidates: Iterable[Tuple[int, str]],
#     threshold: float = 0.82
# ) -> Optional[Tuple[int, str, float]]:
#     """
#     candidates: [(id, question), ...]
#     반환: (best_id, best_question, best_score) 또는 None
#     """
#     best_id = None
#     best_q = None
#     best_s = -1.0
#
#     for cid, cq in candidates:
#         s = combined_similarity(query, cq)
#         if s > best_s:
#             best_id = cid
#             best_q = cq
#             best_s = s
#
#     if best_s >= threshold:
#         return best_id, best_q, best_s
#     return None
# ```
#
# 파일: utils/__init__.py
# ```
# # 패키지 초기화 파일 (비워둠)
# ```
#
# 파일: utils/text.py
# ```
# # -*- coding: utf-8 -*-
# import re
# import unicodedata
#
# _ws_re = re.compile(r"\s+", re.MULTILINE)
# _punct_re = re.compile(r"[^\w\s]", re.UNICODE)
#
# def normalize(text: str) -> str:
#     """
#     - Unicode 정규화(NFKC)
#     - 소문자화
#     - 공백 정리
#     """
#     if text is None:
#         return ""
#     t = unicodedata.normalize("NFKC", text)
#     t = t.lower()
#     t = _ws_re.sub(" ", t).strip()
#     return t
#
# def tokenize(text: str):
#     """
#     간단한 토크나이즈:
#     - normalize 후 비문자/밑줄/숫자 제외 문장부호 제거
#     - 공백 기준 분리
#     """
#     t = normalize(text)
#     t = _punct_re.sub(" ", t)
#     tokens = [tok for tok in t.split(" ") if tok]
#     return tokens
# ```
#
# 설명 마무리:
# - 위 코드는 바로 실행 가능한 최소 구성입니다.
# - 유사도 임계치는 app.py에서 QAService 생성 시 변경할 수 있습니다.
# - 확장 아이디어: FTS5(전문검색) 도입, RapidFuzz/Scikit-learn TF-IDF 유사도, 웹 API(Flask/FastAPI) 레이어 추가, 다국어 토크나이저 적용 등.

# %%
response.output
# Out:
# [ResponseReasoningItem(id='rs_002fddaf9f80500d0069af92ca13e88194aecb3ee87937821a', summary=[], type='reasoning', content=None, encrypted_content=None, status=None),
#  ResponseOutputMessage(id='msg_002fddaf9f80500d0069af92f42d7481948d1be52004c45422', content=[ResponseOutputText(annotations=[], text='아래는 간단한 CLI 기반 Python 앱의 설계와 전체 코드입니다. 동작 요약:\n- SQLite 데이터베이스에 질문/답변(Q/A) 쌍을 저장합니다.\n- 사용자가 질문을 입력하면 저장된 질문들과의 유사도를 계산해 가장 비슷한 질문을 찾습니다.\n- 임계치 이상이면 해당 답변을 반환합니다.\n- 임계치 미만이면 사용자에게 답변을 입력받아 Q/A를 저장합니다.\n- 외부 라이브러리 없이 표준 라이브러리만 사용합니다.\n\n디렉터리 구조\n- app.py\n- README.md\n- requirements.txt\n- db/\n  - __init__.py\n  - database.py\n  - schema.sql\n- services/\n  - __init__.py\n  - qa_service.py\n  - similarity.py\n- utils/\n  - __init__.py\n  - text.py\n- data/ (런타임에 DB 파일 생성)\n\n파일 전체\n\n파일: app.py\n```\n#!/usr/bin/env python3\n# -*- coding: utf-8 -*-\n\nimport sys\nimport signal\nfrom db.database import Database\nfrom services.qa_service import QAService\n\ndef _graceful_exit(signum, frame):\n    print("\\n종료합니다.")\n    sys.exit(0)\n\ndef main():\n    signal.signal(signal.SIGINT, _graceful_exit)\n    signal.signal(signal.SIGTERM, _graceful_exit)\n\n    db = Database(db_path="data/qa.sqlite")\n    db.init_db()\n\n    service = QAService(db=db, similarity_threshold=0.82)\n\n    print("Q/A 매핑 CLI입니다. 질문을 입력하세요. (종료: q 또는 빈 줄)")\n    while True:\n        try:\n            question = input("\\n질문> ").strip()\n        except EOFError:\n            print("\\n종료합니다.")\n            break\n\n        if question.lower() == "q" or question == "":\n            print("종료합니다.")\n            break\n\n        match = service.find_similar(question)\n        if match is not None:\n            matched_id, matched_q, score = match\n            answer = service.get_answer(matched_id)\n            print(f"\\n[매칭된 질문] {matched_q}")\n            print(f"[유사도] {score:.2%}")\n            print(f"[답변]\\n{answer}")\n            continue\n\n        print("유사한 질문이 없습니다.")\n        answer = input("이 질문의 답변을 입력해 주세요: ").strip()\n        if answer == "":\n            print("빈 답변은 저장하지 않습니다.")\n            continue\n\n        saved_id = service.add_qa(question, answer)\n        print(f"저장되었습니다. (id={saved_id})")\n\nif __name__ == "__main__":\n    main()\n```\n\n파일: README.md\n```\n# Q/A 매핑 Python 앱 (CLI)\n\n이 앱은 사용자의 질문을 받아 기존 데이터베이스에서 유사한 질문을 검색하고, 유사한 질문이 없으면 사용자의 답변을 입력받아 새 Q/A를 저장합니다.\n\n## 특징\n- SQLite 기반 로컬 DB (`data/qa.sqlite`)\n- 표준 라이브러리만 사용 (추가 의존성 없음)\n- 간단한 유사도 계산(문장 유사도 + 토큰 Jaccard)과 임계치 기반 매칭\n\n## 설치 및 실행\n1. Python 3.8 이상을 권장합니다.\n2. (선택) 가상환경 생성\n   - macOS/Linux:\n     ```bash\n     python3 -m venv .venv\n     source .venv/bin/activate\n     ```\n   - Windows (PowerShell):\n     ```powershell\n     python -m venv .venv\n     .\\.venv\\Scripts\\Activate.ps1\n     ```\n3. 의존성 설치\n   ```bash\n   pip install -r requirements.txt\n   ```\n4. 실행\n   ```bash\n   python app.py\n   ```\n\n## 사용법\n- 프롬프트에 질문을 입력하면 기존 질문들과의 유사도를 계산해 가장 비슷한 질문을 찾습니다.\n- 유사한 질문이 임계치(기본 0.82) 이상이면 해당 답변을 표시합니다.\n- 없으면 답변을 입력하라는 메시지가 나오며, 입력 시 데이터베이스에 저장됩니다.\n- 종료하려면 빈 줄 또는 `q` 입력.\n\n## 데이터베이스\n- 파일: `data/qa.sqlite`\n- 테이블: `qa_pairs(id, question, answer, created_at, updated_at)`\n\n## 참고\n- 유사도는 `difflib.SequenceMatcher` 기반 문자 유사도와 토큰 단위 Jaccard 유사도의 가중 평균으로 계산합니다.\n- ON CONFLICT(UNIQUE question)에 대해 자동 업데이트합니다(가능한 경우). 환경에 따라 구버전 SQLite에서는 REPLACE 전략으로 대체됩니다.\n```\n\n파일: requirements.txt\n```\n# 표준 라이브러리만 사용합니다. 외부 의존성 없음.\n```\n\n파일: db/__init__.py\n```\n# 패키지 초기화 파일 (비워둠)\n```\n\n파일: db/database.py\n```\n# -*- coding: utf-8 -*-\nimport os\nimport sqlite3\nfrom contextlib import contextmanager\n\nSCHEMA_PATH = os.path.join(os.path.dirname(__file__), "schema.sql")\n\nclass Database:\n    def __init__(self, db_path="data/qa.sqlite"):\n        self.db_path = db_path\n        self._ensure_dir()\n\n    def _ensure_dir(self):\n        directory = os.path.dirname(self.db_path)\n        if directory and not os.path.exists(directory):\n            os.makedirs(directory, exist_ok=True)\n\n    @contextmanager\n    def connect(self):\n        conn = sqlite3.connect(self.db_path)\n        try:\n            conn.row_factory = sqlite3.Row\n            co ...

# %% [markdown]
# ## 추론 기반 코드 자동 생성 실습
#
# **"숫자로 이루어진 문자열이 주어질 때, 해당 숫자의 평균과 중앙값을 구하는 Python 함수를 작성하라."**
# 예를 들어 `"1, 5, 3, 8, 2"`라는 문자열이 입력되면 평균은 `3.8`, 중앙값은 `3`입니다.
#
#
# * 추론 모델을 사용하여 위 문제를 해결하는 **Python 코드**를 생성하세요.
# * `reasoning={"effort": "medium"}` 또는 `reasoning={"effort": "high"}` 옵션을 사용하여 **모델의 내부 추론 과정**을 유도하세요.
# * 코드 실행 결과가 **정확한지 직접 검증**해보세요.
#
# ### 구현 조건
#
# * 문자열을 숫자 리스트로 변환하는 전처리 로직 포함
# * 평균(average)과 중앙값(median)을 계산하는 함수 구성
# * 코드 내에 주석 또는 단계별 설명이 포함되도록 모델에게 유도
# * 출력값 확인을 위한 예제 입력 포함 (`"1, 5, 3, 8, 2"`)
#
# * reasoning effort를 `low`, `medium`, `high`로 바꿔가며 결과물 비교
# * `json.loads()`로 실행 가능한 함수 형태로 모델이 응답하도록 유도해보기
