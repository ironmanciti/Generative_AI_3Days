# %% [markdown]
# # 08. Agent Visualization (에이전트 시각화)
#
# OpenAI Agent SDK는 **Graphviz**를 사용하여 에이전트 구조를 시각적으로 표현하는 기능을 제공합니다.
#
# ### 시각화가 보여주는 것:
# - **노란색 박스**: 에이전트 (Agent)
# - **녹색 타원**: 도구 (Tool)
# - **회색 박스**: MCP 서버
# - **실선 화살표**: 핸드오프 연결
# - **점선 화살표**: 도구 연결
# - **대시선 화살표**: MCP 서버 연결
#
# ### 설치:
# ```bash
# pip install "openai-agents[viz]"
# ```
#
# Graphviz도 시스템에 설치되어 있어야 합니다:
# - Windows: `choco install graphviz` 또는 https://graphviz.org/download/ 에서 설치
# - Mac: `brew install graphviz`
# - Linux: `apt install graphviz`
#
# ### Google Colab 에서 실행

# %%
# !apt-get install -y graphviz  # Colab에서 실행 시 주석 해제
pip install "openai-agents[viz]"
# Out:
# Collecting openai-agents[viz]
#   Downloading openai_agents-0.10.2-py3-none-any.whl.metadata (13 kB)
# Collecting griffe<2,>=1.5.6 (from openai-agents[viz])
#   Downloading griffe-1.15.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: mcp<2,>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from openai-agents[viz]) (1.26.0)
# Requirement already satisfied: openai<3,>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from openai-agents[viz]) (2.23.0)
# Requirement already satisfied: pydantic<3,>=2.12.3 in /usr/local/lib/python3.12/dist-packages (from openai-agents[viz]) (2.12.3)
# Requirement already satisfied: requests<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from openai-agents[viz]) (2.32.4)
# Collecting types-requests<3,>=2.0 (from openai-agents[viz])
#   Downloading types_requests-2.32.4.20260107-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions<5,>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from openai-agents[viz]) (4.15.0)
# Requirement already satisfied: graphviz>=0.17 in /usr/local/lib/python3.12/dist-packages (from openai-agents[viz]) (0.21)
# Collecting colorama>=0.4 (from griffe<2,>=1.5.6->openai-agents[viz])
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio>=4.5 in /usr/local/lib/python3.12/dist-packages (from mcp<2,>=1.19.0->openai-agents[viz]) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp<2,>=1.19.0->openai-agents[viz]) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2,>=1.19.0->openai-agents[viz]) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp<2,>=1.19.0->openai-agents[viz]) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp<2,>=1.19.0->openai-agents[viz]) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents[viz]) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp<2,>=1.19.0->openai-agents[viz]) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2,>=1.19.0->openai-agents[viz]) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp<2,>=1.19.0->openai-agents[viz]) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2,>=1.19.0->openai-agents[viz]) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2,>=1.19.0->openai-agents[viz]) (0.41.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3,>=2.19.0->openai-agents[viz]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3,>=2.19.0->openai-agents[viz]) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3,>=2.19.0->openai-agents[viz]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3,>=2.19.0->openai-agents[viz]) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.12.3->openai-agents[viz]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.12.3->openai-agents[viz]) (2.41.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->openai-agents[viz]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->openai-agents[viz]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->openai-agents[viz]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->openai-agents[viz]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.1->mcp<2,>=1.19.0->openai-agents[viz]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.19.0->openai-agents[viz]) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents[viz]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents[viz]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents[viz]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents[viz]) (0.30.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.5.2->mcp<2,>=1.19.0->openai-agents[viz]) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents[viz]) (43.0.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.31.1->mcp<2,>=1.19.0->openai-agents[viz]) (8.3.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents[viz]) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents[viz]) (3.0)
# Downloading griffe-1.15.0-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 3.5 MB/s eta 0:00:00
# Downloading types_requests-2.32.4.20260107-py3-none-any.whl (20 kB)
# Downloading openai_agents-0.10.2-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 14.6 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: types-requests, colorama, griffe, openai-agents
# Successfully installed colorama-0.4.6 griffe-1.15.0 openai-agents-0.10.2 types-requests-2.32.4.20260107

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import openai

Model = "gpt-5-nano"

# %% [markdown]
# ## 1. 기본 시각화 - 단일 에이전트 + 도구

# %%
from agents import Agent, function_tool
from agents.extensions.visualization import draw_graph

@function_tool
def get_weather(city: str) -> str:
    """주어진 도시의 날씨 정보를 반환합니다."""
    return f"{city}의 날씨는 맑음, 기온 22도입니다."

@function_tool
def get_time(city: str) -> str:
    """주어진 도시의 현재 시간을 반환합니다."""
    return f"{city}의 현재 시간은 오후 3시입니다."

weather_agent = Agent(
    name="날씨 도우미",
    instructions="날씨와 시간 정보를 제공하는 도우미입니다.",
    model=Model,
    tools=[get_weather, get_time],
)

# 에이전트 구조를 시각화
graph = draw_graph(weather_agent)
graph

# %% [markdown]
# ## 2. 핸드오프가 있는 다중 에이전트 시각화
#
# 여러 에이전트가 핸드오프로 연결된 구조를 시각화합니다.

# %%
korean_agent = Agent(
    name="한국어 에이전트",
    instructions="한국어로만 응답합니다.",
    model=Model,
)

english_agent = Agent(
    name="English Agent",
    instructions="You only respond in English.",
    model=Model,
)

triage_agent = Agent(
    name="분류 에이전트",
    instructions="사용자의 요청 언어에 따라 적절한 에이전트에게 전달합니다.",
    model=Model,
    handoffs=[korean_agent, english_agent],
)

# 핸드오프 관계를 시각화
graph = draw_graph(triage_agent)
graph

# %% [markdown]
# ## 3. 복잡한 에이전트 구조 시각화
#
# 도구 + 핸드오프가 결합된 실전에 가까운 구조를 시각화합니다.

# %%
@function_tool
def check_order_status(order_id: str) -> str:
    """주문 상태를 조회합니다."""
    return f"주문 {order_id}: 배송 중"

@function_tool
def process_refund(order_id: str, reason: str) -> str:
    """환불을 처리합니다."""
    return f"주문 {order_id} 환불 처리 완료 (사유: {reason})"

@function_tool
def search_faq(query: str) -> str:
    """FAQ 데이터베이스에서 질문을 검색합니다."""
    return f"FAQ 검색 결과: '{query}'에 대한 답변..."

# 전문 에이전트 정의
order_agent = Agent(
    name="주문 담당",
    instructions="주문 조회 및 상태 확인을 담당합니다.",
    model=Model,
    tools=[check_order_status],
)

refund_agent = Agent(
    name="환불 담당",
    instructions="환불 요청을 처리합니다.",
    model=Model,
    tools=[process_refund],
)

faq_agent = Agent(
    name="FAQ 담당",
    instructions="자주 묻는 질문에 답변합니다.",
    model=Model,
    tools=[search_faq],
)

# 총괄 에이전트
customer_support = Agent(
    name="고객 지원 총괄",
    instructions="고객의 요청을 분류하여 적절한 전문 에이전트에게 전달합니다.",
    model=Model,
    handoffs=[order_agent, refund_agent, faq_agent],
)

# 전체 구조를 시각화
graph = draw_graph(customer_support)
graph

# %% [markdown]
# ## 4. 시각화 저장
#
# 생성된 그래프를 파일로 저장할 수 있습니다.

# %%
# 파일로 저장
draw_graph(customer_support, filename="customer_support_graph")
print("customer_support_graph 파일이 생성되었습니다.")
# Out:
# customer_support_graph 파일이 생성되었습니다.

# %% [markdown]
# ### 정리
#
# | 기능 | 코드 | 설명 |
# |------|------|------|
# | 기본 시각화 | `draw_graph(agent)` | Jupyter에서 인라인 표시 |
# | 파일 저장 | `draw_graph(agent, filename="name")` | PDF 파일로 저장 |
# | 브라우저 열기 | `draw_graph(agent).view()` | 시스템 기본 뷰어로 열기 |
#
# **시각화를 활용하면:**
# - 복잡한 에이전트 관계를 한눈에 파악 가능
# - 핸드오프 흐름 검증에 유용
# - 문서화 및 팀 커뮤니케이션에 활용
