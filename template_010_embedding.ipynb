# %% [markdown]
# # Embedding
# OpenAI의 텍스트 임베딩은 텍스트 문자열의 관련성을 측정합니다. 임베딩은 일반적으로 다음 용도로 사용됩니다.
#
# - 두 텍스트 사이의 관련성을 측정하는 데 사용할 수 있는 텍스트의 숫자 표현
#
# 임베딩은 부동 소수점 숫자로 표시되는 벡터입니다. 두 벡터 사이의 거리는 관련성 을 측정합니다. 거리가 작을수록 관련성이 높음을 나타내고, 거리가 멀면 관련성이 낮다는 것을 나타냅니다.
#
# <img src=https://cdn.sanity.io/images/vr8gru94/production/e016bbd4d7d57ff27e261adf1e254d2d3c609aac-2447x849.png width=600 />

# %%
# OpenAI 임베딩(text-embedding-3-small) 모델을 사용한 문장 임베딩 예제

# %%
# OpenAI API 키를 환경변수에서 가져와 클라이언트 생성
# 샘플 데이터: 간단한 문장들의 모음

# %%
# OpenAI Embedding API를 사용하여 문장 임베딩 함수
def get_embeddings(texts, model='text-embedding-3-small'):

# %%
# 문장 임베딩 실행

# %%
# 임베딩 결과 확인

# %%
# 임베딩 결과를 DataFrame으로 변환하여 시각화

# %%
# 문장 간 코사인 유사도 계산

# %% [markdown]
# ### 실습 문제
#
# 여러 후보 문장 중에서 질의(query) 문장과 의미가 가장 비슷한 문장을 임베딩 코사인 유사도로 찾는 **간단한 의미 검색**을 구현하세요.
#
# 1. 아래 4개의 한글 문장을 후보로 준비하세요.
#    - `"강아지가 공원에서 신나게 뛰어놀고 있다."`
#    - `"고양이가 따뜻한 소파에서 잠을 잔다."`
#    - `"주식 시장이 큰 폭으로 하락했다."`
#    - `"투자자들이 증시 폭락으로 큰 손실을 보았다."`
# 2. `text-embedding-3-small` 모델과 앞에서 정의한 `get_embeddings()` 함수로 후보 문장과 질의 문장을 임베딩하세요.
# 3. `cosine_similarity` 로 질의와 각 후보의 유사도를 계산하고, 유사도가 가장 높은 문장과 그 점수를 출력하세요.
#
# ### 테스트 입력 예시
#
# - 질의: `"반려동물이 즐겁게 놀고 있다."` → 가장 유사: `"강아지가 공원에서 신나게 뛰어놀고 있다."`
# - 질의: `"코스피가 폭락했다."` → 가장 유사: `"투자자들이 증시 폭락으로 큰 손실을 보았다."`
